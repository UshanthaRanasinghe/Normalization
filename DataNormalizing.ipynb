# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("D:\\mypython\\trial\\Ex_1.csv")

# %%
#arr = data.to_numpy()
#print(arr)

# %%
#x = data.pden
#x=((data.pden-min(x))/(max(x)-min(x)))
data['Normalized']=((data['pden']-min(data['pden']))/(max(data['pden'])-min(data['pden']))).tolist()
#data['Normalized']= ((data.pden-min(x))/(max(x)-min(x))).tolist()
data
# Out:
#     DS_CODE    DISTRICT_N                        DSD   pden  Normalized
# 0        20  Anuradhapura           Galenbindunuwewa  174.4    0.172492
# 1        21  Anuradhapura                    Galnewa  272.0    0.296099
# 2        22  Anuradhapura               Horowpothana   47.3    0.011525
# 3        23  Anuradhapura                  Ipalogama  285.6    0.313323
# 4        24  Anuradhapura          Kahatagasdigiliya  124.3    0.109043
# 5        25  Anuradhapura             Kebithigollewa   39.2    0.001266
# 6        26  Anuradhapura                   Kekirawa  193.3    0.196429
# 7        27  Anuradhapura            Mahavilachchiya   38.2    0.000000
# 8        28  Anuradhapura              Medawachchiya  105.1    0.084726
# 9        29  Anuradhapura                 Mihinthale  167.2    0.163374
# 10       30  Anuradhapura               Nachchadoowa  315.1    0.350684
# 11       31  Anuradhapura              Nochchiyagama   66.3    0.035588
# ...

# %%
import numpy as np
import pandas as pd

#create pandas DataFrame
df = pd.DataFrame({'points': [25, 12, 15, 14, 19, 23, 25, 29],
                   'assists': [5, 7, 7, 9, 12, 9, 9, 4],
                   'rebounds': [11, 8, 10, 6, 6, 5, 9, 12]})

print(df)
#create NumPy array for 'blocks'
blocks = np.array([2, 3, 1, 0, 2, 7, 8, 2])

#add 'blocks' array as new column in DataFrame
df['blocks'] = blocks.tolist()

#display the DataFrame
print(df)
